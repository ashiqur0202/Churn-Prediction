# %%
import pandas as pd

# %%
df = pd.read_csv("data/mfs_data.csv")

# %%
df.sample(30)
# Out:
#         Unnamed: 0    txn_date  account_number  txn_amount    txn_type
# 78495      3310330  2023-06-20  70352179849861       200.0    cash_out
# 577743     5374352  2023-09-16  76926895959062      1000.0     cash_in
# 705360     3762158  2023-07-11  77343387048195      1000.0     cash_in
# 181387     2935979  2023-06-05  87224278636468       400.0     payment
# 148619      756738  2023-02-11  32826329399115      1950.0    cash_out
# 235627     2795041  2023-05-30  40522514018974     14500.0    cash_out
# 720666     5485365  2023-09-20  21043395952948     25000.0  send_money
# 671812     2288281  2023-05-06  68063205939641     25000.0    cash_out
# 656795     2936555  2023-06-05  41892055276749      2200.0     cash_in
# 704858      692833  2023-02-07  65580825881902       250.0     cash_in
# 160063     6335570  2023-10-24  99033488535929       200.0    cash_out
# 129809     5256433  2023-09-11  41400509516525     25000.0    cash_out
# ...
